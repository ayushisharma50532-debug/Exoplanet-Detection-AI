# %%
# Ayushi's First Notebook for NASA Hackathon 🚀

import pandas as pd
import matplotlib.pyplot as plt

# Example mini dataset (we will replace with Kepler/TESS later)
data = {
    "id": [1, 2],
    "time1": [0.99, 1.00],
    "time2": [1.00, 1.00],
    "time3": [0.98, 1.00],
    "time4": [1.01, 1.00],
    "label": [1, 0]  # 1 = planet, 0 = no planet
}

df = pd.DataFrame(data)

print("First 5 rows:")
print(df.head())

# Plot a simple light curve
plt.plot([data["time1"][0], data["time2"][0], data["time3"][0], data["time4"][0]])
plt.title("Sample Light Curve")
plt.xlabel("Time Steps")
plt.ylabel("Brightness")
plt.show()
# Out:
# First 5 rows:
#    id  time1  time2  time3  time4  label
# 0   1   0.99    1.0   0.98   1.01      1
# 1   2   1.00    1.0   1.00   1.00      0
